# %%
# Veri setini okuma işlemi
import pandas as pd
import warnings
crypto_data = pd.read_csv('BinanceCrypto.csv', index_col=0)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
crypto_data.head()
crypto_data.tail()
# Out:
#                   date    symbol     open     high      low    close  \
# unix
# 1503273600  2017-08-21  BTC/USDT  4086.29  4119.62  3911.79  4016.00
# 1503187200  2017-08-20  BTC/USDT  4139.98  4211.08  4032.62  4086.29
# 1503100800  2017-08-19  BTC/USDT  4108.37  4184.69  3850.00  4139.98
# 1503014400  2017-08-18  BTC/USDT  4285.08  4371.52  3938.77  4108.37
# 1502928000  2017-08-17  BTC/USDT  4469.93  4485.39  4200.74  4285.08
#
#             Volume BTC  Volume USDT  tradecount
# unix
# 1503273600      685.12   2770592.06         NaN
# 1503187200      463.54   1915636.35         NaN
# 1503100800      371.15   1508239.39         NaN
# 1503014400     1178.07   4994493.56         NaN
# 1502928000      647.86   2812379.11         NaN

# %%
# getting the shape of the data: total number of rows and columns in the data set using ".shape"
crypto_data.shape
#print(crypto_data.columns[0])
#print(crypto_data.iloc[:, 0])
# Out:
# (1381, 9)

# %%
crypto_data.values
# Out:
# array([['2021-05-27 00:00:00', 'BTC/USDT', 39241.92, ..., 328.7373,
#         12868082.0386733, 7097.0],
#        ['2021-05-26 00:00:00', 'BTC/USDT', 38324.72, ..., 104780.773396,
#         4113717505.26356, 2432319.0],
#        ['2021-05-25 00:00:00', 'BTC/USDT', 38810.99, ..., 111996.228404,
#         4253519579.37873, 2508310.0],
#        ...,
#        ['2017-08-19', 'BTC/USDT', 4108.37, ..., 371.15, 1508239.39, nan],
#        ['2017-08-18', 'BTC/USDT', 4285.08, ..., 1178.07, 4994493.56, nan],
#        ['2017-08-17', 'BTC/USDT', 4469.93, ..., 647.86, 2812379.11, nan]],
#       dtype=object)

# %%
# sample will randomly "sample" your dataset
crypto_data.sample(10)
# Out:
#                unix                 date    symbol      open      high  \
# 294   1596672000000  2020-08-06 00:00:00  BTC/USDT  11744.91  11900.00
# 1193  1518998400000  2018-02-19 00:00:00  BTC/USDT  10375.01  11250.00
# 986   1536883200000  2018-09-14 00:00:00  BTC/USDT   6487.39   6584.99
# 99    1613520000000  2021-02-17 00:00:00  BTC/USDT  49133.45  52618.74
# 160   1608249600000  2020-12-18 00:00:00  BTC/USDT  22797.15  23285.18
# 632   1567468800000  2019-09-03 00:00:00  BTC/USDT  10340.00  10773.00
# 1090  1527897600000  2018-06-02 00:00:00  BTC/USDT   7521.01   7697.33
# 105   1613001600000  2021-02-11 00:00:00  BTC/USDT  44807.58  48678.90
# 389   1588464000000  2020-05-03 00:00:00  BTC/USDT   8972.58   9200.00
# 792   1553644800000  2019-03-27 00:00:00  BTC/USDT   3948.77   4048.00
#
#            low     close    Volume BTC   Volume USDT  tradecount
# 294   11562.50  11762.46  63529.085020  7.464792e+08    919918.0
# ...

# %%
# we need an overview of the data types for each column
crypto_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1381 entries, 0 to 1380
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   unix         1381 non-null   int64
#  1   date         1381 non-null   object
#  2   symbol       1381 non-null   object
#  3   open         1381 non-null   float64
#  4   high         1381 non-null   float64
#  5   low          1381 non-null   float64
#  6   close        1381 non-null   float64
#  7   Volume BTC   1381 non-null   float64
#  8   Volume USDT  1381 non-null   float64
#  9   tradecount   1257 non-null   float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 108.0+ KB

# %%
crypto_data.describe().T
# Out:
#               count          mean           std           min           25%  \
# unix         1381.0  1.427176e+12  4.489371e+11  1.502928e+09  1.532650e+12
# open         1381.0  1.275463e+04  1.308552e+04  3.189020e+03  6.511010e+03
# high         1381.0  1.316335e+04  1.354131e+04  3.276500e+03  6.639000e+03
# low          1381.0  1.228499e+04  1.254436e+04  2.817000e+03  6.379700e+03
# close        1381.0  1.277977e+04  1.310298e+04  3.189020e+03  6.514960e+03
# Volume BTC   1381.0  4.927657e+04  3.752524e+04  2.257600e+02  2.672069e+04
# Volume USDT  1381.0  8.035923e+08  1.308131e+09  9.677533e+05  1.875184e+08
# tradecount   1257.0  6.936309e+05  7.275301e+05  7.097000e+03  2.304310e+05
#
#                       50%           75%           max
# unix         1.562458e+12  1.592266e+12  1.622074e+12
# open         8.655880e+03  1.108900e+04  6.357501e+04
# high         8.879990e+03  1.147300e+04  6.485400e+04
# low          8.351000e+03  1.078845e+04  6.202000e+04
# ...

# %%
# Boş verilerin olup olmadığını True/False olarak gösterir
crypto_data.isna()
crypto_data.isnull()
# Out:
#        unix   date  symbol   open   high    low  close  Volume BTC  \
# 0     False  False   False  False  False  False  False       False
# 1     False  False   False  False  False  False  False       False
# 2     False  False   False  False  False  False  False       False
# 3     False  False   False  False  False  False  False       False
# 4     False  False   False  False  False  False  False       False
# ...     ...    ...     ...    ...    ...    ...    ...         ...
# 1376  False  False   False  False  False  False  False       False
# 1377  False  False   False  False  False  False  False       False
# 1378  False  False   False  False  False  False  False       False
# 1379  False  False   False  False  False  False  False       False
# 1380  False  False   False  False  False  False  False       False
#
#       Volume USDT  tradecount
# 0           False       False
# 1           False       False
# 2           False       False
# 3           False       False
# ...

# %%
crypto_data.notnull()
# Out:
#       unix  date  symbol  open  high   low  close  Volume BTC  Volume USDT  \
# 0     True  True    True  True  True  True   True        True         True
# 1     True  True    True  True  True  True   True        True         True
# 2     True  True    True  True  True  True   True        True         True
# 3     True  True    True  True  True  True   True        True         True
# 4     True  True    True  True  True  True   True        True         True
# ...    ...   ...     ...   ...   ...   ...    ...         ...          ...
# 1376  True  True    True  True  True  True   True        True         True
# 1377  True  True    True  True  True  True   True        True         True
# 1378  True  True    True  True  True  True   True        True         True
# 1379  True  True    True  True  True  True   True        True         True
# 1380  True  True    True  True  True  True   True        True         True
#
#       tradecount
# 0           True
# 1           True
# ...

# %%
# Veri setindeki kayıp, eksik (missing) değerlerin özellik bazlı sayısı
# Çıktı: Her bir özelliğe ait kayıp değerlerin sayısını ekrana basar
print("Özellik Bazlı Kayıp Değerlerin Sayısı:")
print(crypto_data.isnull().sum())
# Out:
# Özellik Bazlı Kayıp Değerlerin Sayısı:
# unix             0
# date             0
# symbol           0
# open             0
# high             0
# low              0
# close            0
# Volume BTC       0
# Volume USDT      0
# tradecount     124
# dtype: int64

# %%
# sort the sum of NaN values
crypto_data.isna().sum().sort_values(ascending=False)
# Out:
# tradecount     124
# unix             0
# date             0
# symbol           0
# open             0
# high             0
# low              0
# close            0
# Volume BTC       0
# Volume USDT      0
# dtype: int64

# %%
missingPercentages = crypto_data.isna().sum().sort_values(ascending = False)/len(crypto_data)*100
print(missingPercentages)
# Out:
# tradecount     8.979001
# unix           0.000000
# date           0.000000
# symbol         0.000000
# open           0.000000
# high           0.000000
# low            0.000000
# close          0.000000
# Volume BTC     0.000000
# Volume USDT    0.000000
# dtype: float64

# %%
# Filter: sort out the ones with zeroes
missingPercentages[missingPercentages != 0]
# Out:
# tradecount    8.979001
# dtype: float64

# %%
missingPercentages[missingPercentages != 0].plot(kind='bar', color='pink')
# Out:
# <Axes: >

# %%
crypto_data.tradecount.unique()
#crypto_data.low.unique()
# Out:
# array([   7097., 2432319., 2508310., ...,  116569.,   91956.,      nan])

# %%
## Kayıp değerlerin doldurulması için farklı yöntemler kullanılabilir:
   # 1. Veri grubunu yoksayma
   #2. Veri grubunu elle doldurma
   #3. Kayıp değeri doldurmak için global bir sabit kullanmak
   #4. Kayıp değeri doldurmak için özelliğin (örn. Ortalama veya medyan) bir merkezi eğilim ölçüsünü kullanma
   #5. Verilen veri grubu ile aynı sınıfa ait tüm örnekler için ortalama veya medyan özniteliğini kullanma
   #6. Eksik değeri doldurmak için en olası değeri kullanma

# %%
#1 KAYIP VERİ GRUBUNU YOK SAYMA

# %%
crypto_data.head()
# Out:
#                               date    symbol      open      high       low  \
# unix
# 1622073600000  2021-05-27 00:00:00  BTC/USDT  39241.92  39243.10  39072.00
# 1621987200000  2021-05-26 00:00:00  BTC/USDT  38324.72  40841.00  37800.44
# 1621900800000  2021-05-25 00:00:00  BTC/USDT  38810.99  39791.77  36419.62
# 1621814400000  2021-05-24 00:00:00  BTC/USDT  34681.44  39920.00  34031.00
# 1621728000000  2021-05-23 00:00:00  BTC/USDT  37458.51  38270.64  31111.01
#
#                   close     Volume BTC   Volume USDT  tradecount
# unix
# 1622073600000  39105.47     328.737300  1.286808e+07      7097.0
# 1621987200000  39241.91  104780.773396  4.113718e+09   2432319.0
# 1621900800000  38324.72  111996.228404  4.253520e+09   2508310.0
# 1621814400000  38796.29  161630.893971  5.996773e+09   3510578.0
# 1621728000000  34655.25  217136.046593  7.431242e+09   4082004.0

# %%
crypto_data.dropna(axis=1)
# Out:
#                               date    symbol      open      high       low  \
# unix
# 1622073600000  2021-05-27 00:00:00  BTC/USDT  39241.92  39243.10  39072.00
# 1621987200000  2021-05-26 00:00:00  BTC/USDT  38324.72  40841.00  37800.44
# 1621900800000  2021-05-25 00:00:00  BTC/USDT  38810.99  39791.77  36419.62
# 1621814400000  2021-05-24 00:00:00  BTC/USDT  34681.44  39920.00  34031.00
# 1621728000000  2021-05-23 00:00:00  BTC/USDT  37458.51  38270.64  31111.01
# ...                            ...       ...       ...       ...       ...
# 1503273600              2017-08-21  BTC/USDT   4086.29   4119.62   3911.79
# 1503187200              2017-08-20  BTC/USDT   4139.98   4211.08   4032.62
# 1503100800              2017-08-19  BTC/USDT   4108.37   4184.69   3850.00
# 1503014400              2017-08-18  BTC/USDT   4285.08   4371.52   3938.77
# 1502928000              2017-08-17  BTC/USDT   4469.93   4485.39   4200.74
#
#                   close     Volume BTC   Volume USDT
# unix
# ...

# %%
crypto_data.head()
# Out:
#                               date    symbol      open      high       low  \
# unix
# 1622073600000  2021-05-27 00:00:00  BTC/USDT  39241.92  39243.10  39072.00
# 1621987200000  2021-05-26 00:00:00  BTC/USDT  38324.72  40841.00  37800.44
# 1621900800000  2021-05-25 00:00:00  BTC/USDT  38810.99  39791.77  36419.62
# 1621814400000  2021-05-24 00:00:00  BTC/USDT  34681.44  39920.00  34031.00
# 1621728000000  2021-05-23 00:00:00  BTC/USDT  37458.51  38270.64  31111.01
#
#                   close     Volume BTC   Volume USDT  tradecount
# unix
# 1622073600000  39105.47     328.737300  1.286808e+07      7097.0
# 1621987200000  39241.91  104780.773396  4.113718e+09   2432319.0
# 1621900800000  38324.72  111996.228404  4.253520e+09   2508310.0
# 1621814400000  38796.29  161630.893971  5.996773e+09   3510578.0
# 1621728000000  34655.25  217136.046593  7.431242e+09   4082004.0

# %%
# axis = 0 we drop the whole row
crypto_data.dropna(axis=0)
# Out:
#                               date    symbol      open      high       low  \
# unix
# 1622073600000  2021-05-27 00:00:00  BTC/USDT  39241.92  39243.10  39072.00
# 1621987200000  2021-05-26 00:00:00  BTC/USDT  38324.72  40841.00  37800.44
# 1621900800000  2021-05-25 00:00:00  BTC/USDT  38810.99  39791.77  36419.62
# 1621814400000  2021-05-24 00:00:00  BTC/USDT  34681.44  39920.00  34031.00
# 1621728000000  2021-05-23 00:00:00  BTC/USDT  37458.51  38270.64  31111.01
# ...                            ...       ...       ...       ...       ...
# 1513900800000  2017-12-22 00:00:00  BTC/USDT  15514.03  15699.34  10961.00
# 1513814400000  2017-12-21 00:00:00  BTC/USDT  16480.52  17309.50  14022.00
# 1513728000000  2017-12-20 00:00:00  BTC/USDT  17295.20  17720.35  14777.66
# 1513641600000  2017-12-19 00:00:00  BTC/USDT  18856.25  18950.00  16300.00
# 1513555200000  2017-12-18 00:00:00  BTC/USDT  18860.04  19300.00  17029.98
#
# ...

# %%
#only keep columns with at least %99% non-NaN values
crypto_data.dropna(thresh=0.95*len(crypto_data), axis=1)
# Out:
#                               date    symbol      open      high       low  \
# unix
# 1622073600000  2021-05-27 00:00:00  BTC/USDT  39241.92  39243.10  39072.00
# 1621987200000  2021-05-26 00:00:00  BTC/USDT  38324.72  40841.00  37800.44
# 1621900800000  2021-05-25 00:00:00  BTC/USDT  38810.99  39791.77  36419.62
# 1621814400000  2021-05-24 00:00:00  BTC/USDT  34681.44  39920.00  34031.00
# 1621728000000  2021-05-23 00:00:00  BTC/USDT  37458.51  38270.64  31111.01
# ...                            ...       ...       ...       ...       ...
# 1503273600              2017-08-21  BTC/USDT   4086.29   4119.62   3911.79
# 1503187200              2017-08-20  BTC/USDT   4139.98   4211.08   4032.62
# 1503100800              2017-08-19  BTC/USDT   4108.37   4184.69   3850.00
# 1503014400              2017-08-18  BTC/USDT   4285.08   4371.52   3938.77
# 1502928000              2017-08-17  BTC/USDT   4469.93   4485.39   4200.74
#
#                   close     Volume BTC   Volume USDT
# unix
# ...

# %%
# 3. Kayıp değeri doldurmak için global bir sabit kullanmak

# %%
# Tradecount kolonundaki kayıp değerleri "150" sabit değeri ile doldur ve orijinal veriyi değiştir (inplace=True)
crypto_data['tradecount'].fillna(150, inplace=True)
#crypto_data['tradecount'].fillna(-1).isnull().sum()

# İlgili kolon için kayıp değerleri doldurduktan sonra ortaya çıkan güncel kayıp değer rakamları
print(crypto_data.isnull().sum())
# Out:
# date           0
# symbol         0
# open           0
# high           0
# low            0
# close          0
# Volume BTC     0
# Volume USDT    0
# tradecount     0
# dtype: int64

# %%
# Bu kolon için kayıp değerler 150 sabit değeri ile değiştirildi
crypto_data.head()
# Out:
#                               date    symbol      open      high       low  \
# unix
# 1622073600000  2021-05-27 00:00:00  BTC/USDT  39241.92  39243.10  39072.00
# 1621987200000  2021-05-26 00:00:00  BTC/USDT  38324.72  40841.00  37800.44
# 1621900800000  2021-05-25 00:00:00  BTC/USDT  38810.99  39791.77  36419.62
# 1621814400000  2021-05-24 00:00:00  BTC/USDT  34681.44  39920.00  34031.00
# 1621728000000  2021-05-23 00:00:00  BTC/USDT  37458.51  38270.64  31111.01
#
#                   close     Volume BTC   Volume USDT  tradecount
# unix
# 1622073600000  39105.47     328.737300  1.286808e+07      7097.0
# 1621987200000  39241.91  104780.773396  4.113718e+09   2432319.0
# 1621900800000  38324.72  111996.228404  4.253520e+09   2508310.0
# 1621814400000  38796.29  161630.893971  5.996773e+09   3510578.0
# 1621728000000  34655.25  217136.046593  7.431242e+09   4082004.0

# %%
# 4. Kayıp değeri doldurmak için özelliğin (örn. Ortalama veya medyan) bir merkezi eğilim ölçüsünü kullanma

# %%
# Tradecount kolonundaki kayıp değerleri ilgili kolonun ortalama veya medyan değeri ile doldur ve orijinal veriyi değiştir (inplace=True)
mean = crypto_data['tradecount'].mean()
median = crypto_data['tradecount'].median()

crypto_data['tradecount'].fillna(mean)
# Out:
# unix
# 1622073600000       7097.0
# 1621987200000    2432319.0
# 1621900800000    2508310.0
# 1621814400000    3510578.0
# 1621728000000    4082004.0
#                    ...
# 1503273600           150.0
# 1503187200           150.0
# 1503100800           150.0
# 1503014400           150.0
# 1502928000           150.0
# Name: tradecount, Length: 1381, dtype: float64

# %%
# 5. Verilen veri grubu ile aynı sınıfa ait tüm örnekler için ortalama veya medyan özniteliğini kullanma

# %%
# 'tradocount' özniteliği için "NaN" olan instance'ların toplamı
crypto_data.tradecount.isna().sum()
# Out:
# 0

# %%
# 'tradecount' özniteliği için "NaN" olan instance'ları filtrele
filtered_df = crypto_data[crypto_data['tradecount'].isnull()]
filtered_df
# Out:
# Empty DataFrame
# Columns: [date, symbol, open, high, low, close, Volume BTC, Volume USDT, tradecount]
# Index: []

# %%
# Verileri belirli bir özniteliğe göre grupla
crypto_data.groupby(['tradecount']).mean()
# Out:
#                     open          high           low         close  \
# tradecount
# 150.0        6781.850806   7132.761532   6470.928629   6897.869516
# 7097.0      39241.920000  39243.100000  39072.000000  39105.470000
# 12417.0      7599.000000   7844.000000   7572.090000   7784.020000
# 62065.0      6635.650000   6651.000000   6566.770000   6594.270000
# 68018.0      6585.720000   6663.900000   6580.000000   6590.110000
# ...                  ...           ...           ...           ...
# 4082004.0   37458.510000  38270.640000  31111.010000  34655.250000
# 4269898.0   36671.230000  42451.670000  34850.000000  40526.640000
# 4403349.0   33368.180000  38531.900000  31915.400000  34252.200000
# 4431451.0   38150.020000  38264.740000  30420.000000  35404.470000
# 6331062.0   42849.780000  43584.900000  30000.000000  36690.090000
#
#                Volume BTC   Volume USDT
# tradecount
# 150.0         2810.395161  3.015218e+07
# 7097.0         328.737300  1.286808e+07
# ...

# %%
Mean = lambda x: x.mean()

# %%
Mean(crypto_data.open)
# Out:
# 12754.632751629253

# %%
# Bu veri seti için tahmin etmeye çalıştığımız özellik kapanış fiyatlarını tahmin ettiğimiz için
# "close" kolonu olduğu için sınıf olarak bu kolonu kullanabiliriz.
# Yani close değeri aynı olan örnekler aynı sınıftadır diyebiliriz.

# Geçici bir dataframe oluştur
temp = pd.DataFrame()

# Sınıfların tutulduğu (close) ve kayıp değerlerin (tradecount) doldurulmak istendiği kolonları kopyala
temp['close'] = crypto_data['close'].copy()
temp['tradecount'] = crypto_data['tradecount'].copy()

# Verileri 'close' kolonundaki değere göre grupla. Yani aynı sınıfta olan örnekleri biraraya topla.
# Bu örnek grupları üzerinde dolaş ve aynı sınıftaki tüm örneklerin varsa kayıp değerlerini,
# close dışındaki kolonların ortalaması ile doldur.
temp['tradecount'] = temp.groupby("close").transform(lambda x: x.fillna(x.mean()))

# Sadece 'close' ve 'tradecount' kolonlarını seçmemizin nedeni sadece ilgili kolonun kayıp değerlerinin ortalamasına ulaşmak istememiz.
# Diğer kolonlarıda dahil etseydik, o kolonların ortalamaları da kayıp değerlerin doldurulması için kullanılacaktı.
# Örneğin: open,high... gibi kolonların değerleri de tradecount için doldurulacak kayıp değeri etkileyecekti.
# Ama biz burada sadece 'tradecount' kolonu ile ilgileniyoruz.
crypto_data['tradecount'] = temp['tradecount'].copy()

# %%
sart = crypto_data['close'] == crypto_data.iloc[10]['close']
sinif_ortalama = crypto_data[sart]['tradecount'].mean()

print("10. örneğin alması gereken tradecount değeri:", sinif_ortalama)
print('10. örneğin kayıp değeri doldurulduktan sonra aldığı değer:', crypto_data.iloc[10]['tradecount'])
# Out:
# 10. örneğin alması gereken tradecount değeri: 3216821.0
# 10. örneğin kayıp değeri doldurulduktan sonra aldığı değer: 3216821.0

# %%
# GÜRÜLTÜLÜ VERİ

# %%
import numpy as np
data = [4, 8, 15, 21, 21, 24, 25, 28, 34]
bin_boyutu = 3

# %%
#SMOOTHING BY BIN MEANS

# %%
b1 = np.zeros((int(len(data) / bin_boyutu), bin_boyutu))

for i in range (0, len(data), bin_boyutu):
    k = int(i/bin_boyutu)
    ortalama = sum(data[i: i+bin_boyutu]) / bin_boyutu
    b1[k:bin_boyutu] = ortalama
print("-----------------Ortalama Bin:----------------- \n",b1)
# Out:
# -----------------Ortalama Bin:-----------------
#  [[ 9.  9.  9.]
#  [22. 22. 22.]
#  [29. 29. 29.]]

# %%
#SMOOTHING WITH BOUNDRIES

# %%
b3 = np.zeros((int(len(data) / bin_boyutu), bin_boyutu))

for i in range (0, len(data), bin_boyutu):
    k = int(i/bin_boyutu)
    for j in range (bin_boyutu):
        if (data[i+j]-data[i]) < (data[i+2]-data[i+j]):
            b3[k,j]=data[i]
        else:
            b3[k,j]=data[i+2]

print("-----------------Sınırlayıcı Bin:----------------- \n",b3)
# Out:
# -----------------Sınırlayıcı Bin:-----------------
#  [[ 4.  4. 15.]
#  [21. 21. 24.]
#  [25. 25. 34.]]

# %%
b2 = np.zeros((int(len(data) / bin_boyutu), bin_boyutu))

for i in range (0, len(data), bin_boyutu):
    k = int(i/bin_boyutu)
    b1[k:bin_boyutu] = data[i:i+3]
print("-----------------Eşit Sıklıkta Bin:----------------- \n",b1)
# Out:
# -----------------Eşit Sıklıkta Bin:-----------------
#  [[ 4.  8. 15.]
#  [21. 21. 24.]
#  [25. 28. 34.]]

# %%
#"Open" ve "Close" fiyatları arasındaki ilişki, bir varlığın fiyat trendini anlamak için.
# Özellikle, kapanış fiyatının açılış fiyatından yüksek olması genellikle yükseliş eğilimini,
 #kapanış fiyatının açılış fiyatından düşük olması ise genellikle düşüş eğilimini gösterebilir.

beklenmedik_durum = pd.crosstab(crypto_data['open'], crypto_data['close'], margins=True)
beklenmedik_durum
# Out:
# close     3189.02  3211.72  3224.17  3228.67  3302.06  3380.39  3398.4  \
# open
# 3189.02         0        0        0        0        0        0       0
# 3211.71         0        0        0        1        0        0       0
# 3225.19         0        1        0        0        0        0       0
# 3229.22         0        0        0        0        0        0       0
# 3302.06         0        0        1        0        0        0       0
# ...           ...      ...      ...      ...      ...      ...     ...
# 61334.81        0        0        0        0        0        0       0
# 62959.53        0        0        0        0        0        0       0
# 63158.74        0        0        0        0        0        0       0
# 63575.01        0        0        0        0        0        0       0
# All             1        1        1        1        1        1       1
#
# close     3403.55  3405.37  3410.93  ...  59769.13  59860.0  60002.43  \
# ...

# %%
#FEATURE ENGINEERING

# %%
#En önemli özelliğim close değeri

# %%
corelation = crypto_data.corr() #it,s the corralation matrix to see corelation with features between each other.
corelation
# Out:
#                  open      high       low     close  Volume BTC  Volume USDT  \
# open         1.000000  0.999122  0.998103  0.998060    0.361782     0.859058
# high         0.999122  1.000000  0.997958  0.999139    0.370059     0.865173
# low          0.998103  0.997958  1.000000  0.998846    0.343273     0.841125
# close        0.998060  0.999139  0.998846  1.000000    0.357803     0.854387
# Volume BTC   0.361782  0.370059  0.343273  0.357803    1.000000     0.661001
# Volume USDT  0.859058  0.865173  0.841125  0.854387    0.661001     1.000000
# tradecount   0.812350  0.818090  0.798708  0.809651    0.769015     0.959212
#
#              tradecount
# open           0.812350
# high           0.818090
# low            0.798708
# close          0.809651
# Volume BTC     0.769015
# Volume USDT    0.959212
# tradecount     1.000000

# %%
covariance=crypto_data.cov()
covariance
# Out:
#                      open          high           low         close  \
# open         1.712310e+08  1.770394e+08  1.638383e+08  1.711266e+08
# high         1.770394e+08  1.833670e+08  1.695202e+08  1.772786e+08
# low          1.638383e+08  1.695202e+08  1.573611e+08  1.641789e+08
# close        1.711266e+08  1.772786e+08  1.641789e+08  1.716880e+08
# Volume BTC   1.776486e+08  1.880423e+08  1.615890e+08  1.759288e+08
# Volume USDT  1.470499e+13  1.532550e+13  1.380259e+13  1.464455e+13
# tradecount   7.673318e+09  7.996696e+09  7.232452e+09  7.658027e+09
#
#                Volume BTC   Volume USDT    tradecount
# open         1.776486e+08  1.470499e+13  7.673318e+09
# high         1.880423e+08  1.532550e+13  7.996696e+09
# low          1.615890e+08  1.380259e+13  7.232452e+09
# close        1.759288e+08  1.464455e+13  7.658027e+09
# Volume BTC   1.408144e+09  3.244720e+13  2.083086e+10
# Volume USDT  3.244720e+13  1.711208e+18  9.057641e+14
# ...

# %%
import seaborn as sns
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True, cmap=sns.color_palette( as_cmap=True))
# Out:
# <Axes: >

# %%
crypto_data.corr().abs()["close"].nlargest(11)
# Out:
# close          1.000000
# high           0.999139
# low            0.998846
# open           0.998060
# Volume USDT    0.854387
# tradecount     0.809651
# Volume BTC     0.357803
# Name: close, dtype: float64

# %%
sns.pairplot(data=crypto_data, hue='close')# This is showing scatter plot of all features between close

# %%
species = list(crypto_data.groupby('close'))
sns.scatterplot(data = crypto_data, x = 'open', y = 'high', hue='close')
# Out:
# <Axes: xlabel='open', ylabel='high'>

# %%
# Aim: is there any relation between low and close ?
dd = pd.crosstab(crypto_data['close'], crypto_data['low'], margins=True)
dd
#True False Table.
# Out:
# low       2817.0  3156.26  3165.13  3177.0  3186.0  3216.0  3222.0  3224.6  \
# close
# 3189.02        0        0        1       0       0       0       0       0
# 3211.72        0        1        0       0       0       0       0       0
# 3224.17        0        0        0       1       0       0       0       0
# 3228.67        0        0        0       0       1       0       0       0
# 3302.06        0        0        0       0       0       0       0       0
# ...          ...      ...      ...     ...     ...     ...     ...     ...
# 61334.8        0        0        0       0       0       0       0       0
# 62959.53       0        0        0       0       0       0       0       0
# 63159.98       0        0        0       0       0       0       0       0
# 63575.0        0        0        0       0       0       0       0       0
# All            1        1        1       1       1       1       1       1
#
# ...

# %%
crypto_data.drop('tradecount', inplace=True, axis=1)

# %%
sample=crypto_data.sample(20)#i can test my algorithm in this sample
sample
# Out:
#                               date    symbol      open      high       low  \
# unix
# 1520294400000  2018-03-06 00:00:00  BTC/USDT  11455.00  11455.00  10555.48
# 1535846400000  2018-09-02 00:00:00  BTC/USDT   7201.57   7345.45   7127.00
# 1606176000000  2020-11-24 00:00:00  BTC/USDT  18368.01  19418.97  18018.00
# 1579219200000  2020-01-17 00:00:00  BTC/USDT   8720.15   9041.65   8672.44
# 1540771200000  2018-10-29 00:00:00  BTC/USDT   6489.93   6505.01   6315.00
# 1535673600000  2018-08-31 00:00:00  BTC/USDT   6984.84   7089.00   6888.00
# 1528243200000  2018-06-06 00:00:00  BTC/USDT   7626.64   7699.00   7467.05
# 1586563200000  2020-04-11 00:00:00  BTC/USDT   6858.92   6944.30   6760.00
# 1543017600000  2018-11-24 00:00:00  BTC/USDT   4415.63   4527.00   3824.69
# 1546473600000  2019-01-03 00:00:00  BTC/USDT   3857.57   3862.74   3730.00
# 1603929600000  2020-10-29 00:00:00  BTC/USDT  13266.40  13642.91  12920.77
# ...

# %%
o=[]
for i in crypto_data.columns:
    if crypto_data[i].dtype=='object':
        o.append(i)

Xenc=pd.get_dummies(crypto_data,columns=o)

# %%
Xenc.head(5)
# Out:
#                    open      high       low     close     Volume BTC  \
# unix
# 1622073600000  39241.92  39243.10  39072.00  39105.47     328.737300
# 1621987200000  38324.72  40841.00  37800.44  39241.91  104780.773396
# 1621900800000  38810.99  39791.77  36419.62  38324.72  111996.228404
# 1621814400000  34681.44  39920.00  34031.00  38796.29  161630.893971
# 1621728000000  37458.51  38270.64  31111.01  34655.25  217136.046593
#
#                 Volume USDT  date_2017-08-17  date_2017-08-18  \
# unix
# 1622073600000  1.286808e+07                0                0
# 1621987200000  4.113718e+09                0                0
# 1621900800000  4.253520e+09                0                0
# 1621814400000  5.996773e+09                0                0
# 1621728000000  7.431242e+09                0                0
#
#                date_2017-08-19  date_2017-08-20  ...  \
# unix                                             ...
# ...

# %%
from sklearn.model_selection import train_test_split

# Veri setindeki özellikler
crypto_features = crypto_data.drop("tradecount", axis=1)

# Veri setindeki sınıflar
crypto_targets = crypto_data[["tradecount"]]

# Stratified Örnekleme
X_train, X_test, y_train, y_test = train_test_split(crypto_features, crypto_targets, stratify=crypto_targets)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-a3987a282bfc> in <cell line: 10>()
#       8
#       9 # Stratified Örnekleme
# ---> 10 X_train, X_test, y_train, y_test = train_test_split(crypto_features, crypto_targets, stratify=crypto_targets)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2581         cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2582
# -> 2583         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2584
#    2585     return list(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    2158         to an integer.
#    2159         """
# -> 2160         y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
# ...

# %%
x_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-80784060c951> in <cell line: 1>()
# ----> 1 x_train
#
# NameError: name 'x_train' is not defined

# %%
y_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-27d3425f7a85> in <cell line: 1>()
# ----> 1 y_test
#
# NameError: name 'y_test' is not defined

# %%
print(crypto_data.columns)
print(crypto_data.head())
# Example assuming data is loaded from a CSV file
crypto_data = pd.read_csv('BinanceCrypto.csv')

# Özelliklerin ve sınıfların ayrıştırılması
features = ['unix', 'open', 'high', 'low', 'close', 'Volume BTC',	'Volume USDT', 'tradecount']
# Özellik Matrisi
x = crypto_data.loc[:, features].values
# Sınıf Vektörü
y = crypto_data.loc[:,['tradecount']].values
# Out:
# Index(['date', 'symbol', 'open', 'high', 'low', 'close', 'Volume BTC',
#        'Volume USDT'],
#       dtype='object')
#                               date    symbol      open      high       low  \
# unix
# 1622073600000  2021-05-27 00:00:00  BTC/USDT  39241.92  39243.10  39072.00
# 1621987200000  2021-05-26 00:00:00  BTC/USDT  38324.72  40841.00  37800.44
# 1621900800000  2021-05-25 00:00:00  BTC/USDT  38810.99  39791.77  36419.62
# 1621814400000  2021-05-24 00:00:00  BTC/USDT  34681.44  39920.00  34031.00
# 1621728000000  2021-05-23 00:00:00  BTC/USDT  37458.51  38270.64  31111.01
#
#                   close     Volume BTC   Volume USDT
# unix
# 1622073600000  39105.47     328.737300  1.286808e+07
# 1621987200000  39241.91  104780.773396  4.113718e+09
# 1621900800000  38324.72  111996.228404  4.253520e+09
# 1621814400000  38796.29  161630.893971  5.996773e+09
# 1621728000000  34655.25  217136.046593  7.431242e+09

# %%
from sklearn.decomposition import PCA

# Temel bileşen analizi yöntemi ile veri seti 2 boyutta temsil ediliyor.
# Artık sınıflandırma için 2 özellik kullanılacak
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)

# PCA sonrası elde edilen özellikler görselleştirme için tekrar DataFrame içerisine atılıyor
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])
finalDf = pd.concat([principalDf, crypto_data[['target']]], axis = 1)
finalDf.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-ec83fb51699d> in <cell line: 6>()
#       4 # Artık sınıflandırma için 2 özellik kullanılacak
#       5 pca = PCA(n_components=2)
# ----> 6 principalComponents = pca.fit_transform(x)
#       7
#       8 # PCA sonrası elde edilen özellikler görselleştirme için tekrar DataFrame içerisine atılıyor
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     460         self._validate_params()
# ...
